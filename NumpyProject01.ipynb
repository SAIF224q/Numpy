# %% [markdown]
# we are going to Simulate rolling 2 dice 1000 times → plot distribution (using Matplotlib).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# But first let's start with a basic tutorial of Matplotlib visualization.
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.

# %% [markdown]
# First we have to import matplotlib and pyplot using code. pyplot is submodle
#
# ```python
# import matplotlib.pyplot as plt
# ```
# Than import numpy - ``` import numpy as np ```

# %% [markdown]
# Let's Draw a line in a diagram from position (0,0) to position (6,250):

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Before moving to our main problem let's break it to only one dice and plot its outcome.

# %%
Dice = np.random.randint(1,7,size=(1,1000))
unique_values, counts = np.unique(Dice, return_counts=True)
plt.bar(unique_values, counts)
plt.show()

# %% [markdown]
# Now let's move to our main problem

# %%
Dice_1 = np.random.randint(1,7,size=(1,1000))
Dice_2 = np.random.randint(1,7,size=(1,1000))
Dice_sum = Dice_1 + Dice_2
unique_values, counts = np.unique(Dice_sum, return_counts=True)
plt.bar(unique_values, counts)
plt.show()

# %% [markdown]
# Boom it's done. Bye have a nice day buddy
